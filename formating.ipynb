# %%
print("simapl")
# Out:
# simapl

# %% [markdown]
# ## String formatting

# %%
name="Sadab"
roll=241 

print(f"my name is {name} and my roll no. is {roll}")
# Out:
# my name is Sadab and my roll no. is 241

# %% [markdown]
# Some good concept

# %%
a=2
b=4
c=5

"the no. is {}, {}, {}".format(a,b,c)
# Out:
# 'the no. is 2, 4, 5'

# %% [markdown]
# ## Type casting

# %%
1+2.2+True  # Auto type casting
# Out:
# 4.2

# %%
a=1.9
print(int(a)) # forced type casting
# Out:
# 1

# %%
a=12
print(float(a))
a=12
print(str(a))
a=12
print(bool(a))
a=12
print(complex(a))
# Out:
# 12.0
# 12
# True
# (12+0j)

# %%
int(6.5)+1.2+int(5.5)+bool(0)
# Out:
# 12.2

# %%
a=1
a += 1
print(a)
print("---------------")
a=1
a -= 1
print(a)
print("---------------")
a=1
a/=1
print(a)
print("---------------")
a=1
a%=1
print(a)
print("---------------")
a=1
a*= 1
print(a)
# Out:
# 2
# ---------------
# 0
# ---------------
# 1.0
# ---------------
# 0
# ---------------
# 1

# %%
a=20
b=10

print(a+b)
print(a-b)
print(a/b)
print(a*b)
print(a%b)
print(a//b)
# Out:
# 30
# 10
# 2.0
# 200
# 0
# 2
