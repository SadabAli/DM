# %%
print('simpal')
# Out:
# simpal

# %%
def abc():
    '''
    this is demo funtions
    ''' 
    pass

# %%
print(abc.__doc__)
# Out:
# this is demo funtions

# %%
sq=lambda x : x**2 
sq(2)
# Out:
# 4

# %%
reminder = lambda a, b : a % b
reminder(2,2)
# Out:
# 0

# %%
l=[1,2,3,4,5,6] 

odd = list(filter(lambda x: x % 2 != 0,l))
print(odd)

even = list(filter(lambda x: x % 2 == 0,l))
print(even)
# Out:
# [1, 3, 5]
# [2, 4, 6]

# %%
# 2 list 1->prime, 2->non prime
l=[2,3,4,5,6] 

prime = list(filter(lambda x: x % 2 != 0,l)) # Prime using lambda !possible
print(odd)

even = list(filter(lambda x: x % 2 == 0,l))
print(even)
