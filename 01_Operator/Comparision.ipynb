# %%
print("simpal")
# Out:
# simpal

# %%
a=241
b=242

print(a==b)
print(a!=b)
print(a>b)
print(a<b)
print(a>=b)
print(a<=b)
# Out:
# False
# True
# False
# True
# False
# True

# %%
a=1
b=2
c=3
print(a==b==c)
print(a!=b!=c)
print(a>b>c)
print(a<b<c)
print(a>=b>=c)
print(a<=b<=c)
# Out:
# False
# True
# False
# True
# False
# True

# %% [markdown]
# ## Logical Operator

# %%
a=True
b=False
print(a and b)
print(b or b)
print(not a)
# Out:
# False
# False
# False

# %%
age=20
marks=85
course=True 
# age < 15, marks >90, course
# salary = 50000 

print(age <15 and marks > 90 and course)


# print(age > 18 and salary > 30000)
# Out:
# False

# %%
age += 5
print(age)
age -= 5
print(age)
age *= 1
print(age)
age /= 20
print(age)
# Out:
# 10
# 5
# 5
# 0.25

# %%
print("f" in "Student")
print("z" not in "Student")
# Out:
# False
# True

# %% [markdown]
# ## Keywords

# %%
import keyword 
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ## Strings

# %%
t="Sadab"

# %%
par="""
kjfnweyheirv
ervrtvtre
ewtg4g3g

"""

par
# Out:
# '\nkjfnweyheirv\nervrtvtre\newtg4g3g\n\n'

# %%
print(type(par))
print(len(par))
# Out:
# <class 'str'>
# 34

# %%
a="Student"

# %%
print(a[0])
print(a[1])
print(a[2])
print(a[3])
print(a[4])
print(a[5])
print(a[6])
print("---------------")
print(a[-1])
print(a[-2])
print(a[-3])
print(a[-4])
print(a[-5])
print(a[-6])
print(a[-7])
# Out:
# S
# t
# u
# d
# e
# n
# t
# ---------------
# t
# n
# e
# d
# u
# t
# S

# %%
a="MachineLearning"

# %%
print(a[0:7])
print(a[7:])
print(a[:7])
print(a[:])
# Out:
# Machine
# Learning
# Machine
# MachineLearning

# %%
print(a[5:8])
# Out:
# neL

# %%
print(a[12:])
# Out:
# ing

# %%
print(a[-3:])
# Out:
# ing

# %%
print(a[3:6])
# Out:
# hin

# %%
a="PythonProgramming"
print(a[::3])
print()
# Out:
# PhPgmn

# %%
print(a[::-1])
# Out:
# gnimmargorPnohtyP

# %%
a[-8:-5]
# Out:
# 'Lea'
