# %%
print("Simpal")
# Out:
# Simpal

# %%
a=str(input("Enter your name"))

if (a == "Sadab"):
    print(''' Ohhhhh Nooooooo''')
# Out:
#  Ohhhhh Nooooooo

# %%
a=int(input("Enter any integer"))

if a>6:
    print(a," is greater than 6")
print(a," is smaller than 6")
# Out:
# 4  is smaller than 6

# %%
money=int(input("Enter the money you have"))

if money > 5000:
    print("you can go to the mall")

else:
    print("Beta Aukaat me")
# Out:
# you can go to the mall

# %%
number=int(input("Enter you lucky drow number"))

if number == 888593:
    print("Congratulations!!")
else:
    print("Unlucky hahahahah!!!!")
# Out:
# Unlucky hahahahah!!!!

# %%
pas=int(input("Enter you lucky drow number"))

if pas == 123456:
    print("Opening")
else:
    print("try again")
# Out:
# Opening
