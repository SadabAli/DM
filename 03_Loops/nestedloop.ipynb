# %%
print("simpal")
# Out:
# simpal

# %%
a=[1,2,3]
b=[3,4,5]
for i in a:
    for j in b:
        print(i,j)
# Out:
# 1 3
# 1 4
# 1 5
# 2 3
# 2 4
# 2 5
# 3 3
# 3 4
# 3 5

# %%
a=[1,2,3]
b=[3,4,5]
for i in b:
    for j in a:
        print(i,j)
# Out:
# 3 1
# 3 2
# 3 3
# 4 1
# 4 2
# 4 3
# 5 1
# 5 2
# 5 3

# %%
for i in range(1,6):
    print("*" *i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(1,6):
    print("*" )

# %%
num=int(input("Enter a number"))
result=0
for i in range(1,num + 1):
    result += i
print(result)
# Out:
# 3

# %%
def Sum(num):
    result=0
    for i in range(1,num + 1):
        result += i
    return result

# %%
Sum(2)
# Out:
# 3

# %%
def abc():
    print('efjh')
abc()
# Out:
# efjh

# %%
def add(a,b):
    print(a+b)
add(1,2)
# Out:
# 3

# %%
def add(*args):
    result = 0 
    for i in args:
        result += i 
    return result

# %%
add(1,2,3,4)
# Out:
# 10

# %%
def an():
    return 'sadab'

# %%
an()
# Out:
# 'sadab'

# %%
def fact(n):
    if(n==1):
        return 1
    if (n < 1):
        print("number is not valid") 
    else:
        return(n*fact(n-1))
fact(5)
# Out:
# 120

# %%
fact=1
for i in range(1,6):
    fact *= i 
print(fact)
# Out:
# 120
