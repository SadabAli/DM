# %%
print("simpal")
# Out:
# simpal

# %%
a=[1,2,3]
b=[3,4,5]
for i in a:
    for j in b:
        print(i,j)
# Out:
# 1 3
# 1 4
# 1 5
# 2 3
# 2 4
# 2 5
# 3 3
# 3 4
# 3 5

# %%
a=[1,2,3]
b=[3,4,5]
for i in b:
    for j in a:
        print(i,j)
# Out:
# 3 1
# 3 2
# 3 3
# 4 1
# 4 2
# 4 3
# 5 1
# 5 2
# 5 3

# %%
for i in range(1,6):
    print("*" *i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
for i in range(6,1,-1):
    print("*" *i)
# Out:
# ******
# *****
# ****
# ***
# **

# %%
rows = 5

for i in range(1, rows + 1):
    # Print leading spaces, then print the stars
    print(" " * (rows - i) + "*" * (2 * i - 1))
# Out:
#     *
#    ***
#   *****
#  *******
# *********

# %%
num=4 
for i in range(1,num + 1):
    print((num -i) * " " + ((2*i) -1) * "*")
# Out:
#    *
#   ***
#  *****
# *******
