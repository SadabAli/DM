# %%
print("Simpal")
# Out:
# Simpal

# %%
t=143,232

# %%
t
# Out:
# (143, 232)

# %%
t=()

# %%
t=tuple([123,143,241,242])

# %%
print(t)
print(type(t))
# Out:
# (123, 143, 241, 242)
# <class 'tuple'>

# %%
t=(2,3.3,23.45)

# %%
t=('venvk',3,244,232.243,(2,3.3,23.45))

# %%
t
# Out:
# ('venvk', 3, 244, 232.243, (2, 3.3, 23.45))

# %%
t[0]
# Out:
# 'venvk'

# %%
l=[2,3,43,2,4,4]
l=tuple(l)

# %%
l
# Out:
# (2, 3, 43, 2, 4, 4)

# %%
t=('dfvv',44,34,334.44,[3,2,4,5],[4,3],('ffvd', 'rvrvr'))

# %%
t[4][1:3]
# Out:
# [2, 4]

# %%
del t[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 del t[0]
#
# TypeError: 'tuple' object doesn't support item deletion

# %% [markdown]
# ## Tuple is immutable so we can't delete or add an items

# %%
import numpy as np

# %%
np.random.randint(1,50,10)
# Out:
# array([28, 21, 42, 45, 40, 12, 15, 37, 28, 17], dtype=int32)

# %%
l=[28, 21, 42, 45, 40, 12, 15, 37, 28, 17]
l=tuple(l)

# %%
l.index(40)
# Out:
# 4

# %% [markdown]
# ### in case of multiple occurance of an items, index() return the 1st one only

# %% [markdown]
# # Sorting

# %%
sorted(l,reverse=True)
# Out:
# [45, 42, 40, 37, 28, 28, 21, 17, 15, 12]
