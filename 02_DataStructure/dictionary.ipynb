# %%
print('simpal')
# Out:
# simpal

# %%
d={1:'sadab',
    2:'simpal',
    3:'ali',
    "marks":{
            'math':99,
            'science':98

        }
    }

# %%
d
# Out:
# {1: 'sadab', 2: 'simpal', 3: 'ali'}

# %%
d['marks']['math']
# Out:
# 99

# %%
d.keys()
# Out:
# dict_keys([1, 2, 3, 'marks'])

# %%
d.values()
# Out:
# dict_values(['sadab', 'simpal', 'ali', {'math': 99, 'science': 98}])

# %%
for (keys, values) in d.items():
    print(keys, values)
# Out:
# 1 sadab
# 2 simpal
# 3 ali
# marks {'math': 99, 'science': 98}

# %%
v=[0,1,2,3,[8,{5:[67,89,90,{'area':'south', 'city':"Bengaluru"}]}]]

# %%
v[4][1][5][3]['city']
# Out:
# 'Bengaluru'

# %%
v[4][1][5][2]
# Out:
# 90

# %% [markdown]
# ## Operations

# %%
d
# Out:
# {1: 'sadab', 2: 'simpal', 3: 'ali', 'marks': {'math': 99, 'science': 98}}

# %%
d.update({4:'dimpal'})
print(d)
# Out:
# {1: 'sadab', 2: 'simpal', 3: 'ali', 'marks': {'math': 99, 'science': 98}, 4: 'dimpal'}

# %%
d[5]='Mir'
print(d)
# Out:
# {1: 'sadab', 2: 'simpal', 3: 'ali', 'marks': {'math': 99, 'science': 98}, 4: 'dimpal', 5: 'Mir'}

# %% [markdown]
# ## Deleting

# %%
d.pop(5)
# Out:
# 'Mir'

# %%
d
# Out:
# {1: 'sadab',
#  2: 'simpal',
#  3: 'ali',
#  'marks': {'math': 99, 'science': 98},
#  4: 'dimpal'}

# %%
del d[4]

# %%
d
# Out:
# {1: 'sadab', 2: 'simpal', 3: 'ali', 'marks': {'math': 99, 'science': 98}}

# %%
d.clear()

# %%
del d

# %%
d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 d
#
# NameError: name 'd' is not defined
